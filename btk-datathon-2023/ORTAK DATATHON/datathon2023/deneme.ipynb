# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# CSV dosyasını DataFrame'e dönüştürme
train = pd.read_csv("train.csv")
test = pd.read_csv("test_x.csv")

# %%
test.head()
# Out:
#    index Cinsiyet Yaş Grubu Medeni Durum         Eğitim Düzeyi  \
# 0      0    Erkek     51-60         Evli  Yüksek Lisans Mezunu
# 1      1    Erkek     41-50        Bekar           Lise Mezunu
# 2      2    Kadın       >60         Evli             Eğitimsiz
# 3      3    Kadın     51-60         Evli         Doktora Ötesi
# 4      4    Erkek     18-30         Evli  Yüksek Lisans Mezunu
#
#                   İstihdam Durumu  Yıllık Ortalama Gelir   Yaşadığı Şehir  \
# 0  Düzenli ve Ücretli Bir İşi Var          365331.930346  Köy veya Kasaba
# 1  İşsiz veya Düzenli Bir İşi Yok          414899.236174      Büyük Şehir
# 2  İşsiz veya Düzenli Bir İşi Yok          152825.872271      Küçük Şehir
# 3  Düzenli ve Ücretli Bir İşi Var          489052.908472  Köy veya Kasaba
# 4             Kendi İşinin Sahibi          323635.711534      Küçük Şehir
#
#   En Çok İlgilendiği Ürün Grubu  Yıllık Ortalama Satın Alım Miktarı  \
# 0                         Giyim                         5566.587664
# ...

# %%
train.head()
# Out:
#    index Cinsiyet Yaş Grubu Medeni Durum         Eğitim Düzeyi  \
# 0      0    Kadın     31-40        Bekar  Yüksek Lisans Mezunu
# 1      1    Erkek       >60         Evli           Lise Mezunu
# 2      2    Erkek     18-30        Bekar           Lise Mezunu
# 3      3    Erkek     51-60         Evli           Lise Mezunu
# 4      4    Erkek     31-40         Evli       Ortaokul Mezunu
#
#                   İstihdam Durumu  Yıllık Ortalama Gelir Yaşadığı Şehir  \
# 0  Düzenli ve Ücretli Bir İşi Var          748266.440879    Büyük Şehir
# 1             Kendi İşinin Sahibi          246298.609605    Küçük Şehir
# 2  Düzenli ve Ücretli Bir İşi Var          268582.732360    Küçük Şehir
# 3             Kendi İşinin Sahibi          327721.837865         Kırsal
# 4  İşsiz veya Düzenli Bir İşi Yok          397431.626948    Büyük Şehir
#
#       En Çok İlgilendiği Ürün Grubu  Yıllık Ortalama Satın Alım Miktarı  \
# 0  Elektronik ve Teknolojik Ürünler                        32010.900881
# ...

# %%
spor_verileri = train[train["En Çok İlgilendiği Ürün Grubu"]
                      == "Spor Malzemeleri"]
spor_verileri
spor_verileri["Öbek İsmi"].value_counts()
# Out:
# Öbek İsmi
# obek_5    225
# obek_3    205
# obek_4    153
# obek_6    139
# obek_8    124
# obek_7    101
# obek_2     45
# obek_1      9
# Name: count, dtype: int64

# %%
train["Eğitime Devam Etme Durumu"].value_counts()
# Out:
# Eğitime Devam Etme Durumu
# Etmiyor    4554
# Ediyor      906
# Name: count, dtype: int64

# %%
obek_2_verileri = train[train["Öbek İsmi"] == "obek_2"]
obek_2_verileri.tail(23)

# obek_2_verileri["Medeni Durum"].value_counts()
# Evli     424
# Bekar    123

# obek_2_verileri["Yaş Grubu"].value_counts()
# 18-30    134
# 41-50    109
# 31-40    106
# 51-60     99
# >60       99

# obek_2_verileri["Cinsiyet"].value_counts()
# Kadın    528
# Erkek     19

# obek_2_verileri["Yıllık Ortalama Gelir"].mean()
# Out:
#       index Cinsiyet Yaş Grubu Medeni Durum         Eğitim Düzeyi  \
# 5248   5248    Kadın     18-30         Evli     Üniversite Mezunu
# 5255   5255    Kadın     41-50         Evli        İlkokul Mezunu
# 5258   5258    Kadın     51-60         Evli             Eğitimsiz
# 5261   5261    Kadın     18-30         Evli        İlkokul Mezunu
# 5266   5266    Kadın     31-40         Evli     Üniversite Mezunu
# 5274   5274    Kadın       >60         Evli             Eğitimsiz
# 5286   5286    Kadın     18-30         Evli     Yüksekokul Mezunu
# 5292   5292    Kadın     31-40         Evli  Yüksek Lisans Mezunu
# 5324   5324    Kadın     18-30         Evli  Yüksek Lisans Mezunu
# 5342   5342    Kadın     41-50         Evli           Lise Mezunu
# 5347   5347    Kadın     31-40        Bekar        İlkokul Mezunu
# 5348   5348    Kadın     41-50         Evli     Yüksekokul Mezunu
# 5363   5363    Kadın     18-30         Evli           Lise Mezunu
# ...

# %%
obek_3_verileri = train[train["Öbek İsmi"] == "obek_3"]
obek_3_verileri.head(25)
# Out:
#      index Cinsiyet Yaş Grubu Medeni Durum         Eğitim Düzeyi  \
# 3        3    Erkek     51-60         Evli           Lise Mezunu
# 4        4    Erkek     31-40         Evli       Ortaokul Mezunu
# 6        6    Kadın     18-30         Evli           Lise Mezunu
# 8        8    Erkek     51-60        Bekar     Üniversite Mezunu
# 13      13    Erkek     51-60         Evli     Üniversite Mezunu
# 21      21    Erkek     51-60        Bekar           Lise Mezunu
# 32      32    Erkek     18-30         Evli        İlkokul Mezunu
# 38      38    Erkek     31-40        Bekar           Lise Mezunu
# 64      64    Erkek     51-60         Evli  Yüksek Lisans Mezunu
# 65      65    Erkek     18-30         Evli             Eğitimsiz
# 91      91    Erkek       >60         Evli       Ortaokul Mezunu
# 98      98    Erkek     31-40         Evli           Lise Mezunu
# 112    112    Erkek     41-50         Evli     Yüksekokul Mezunu
# ...

# %%
obek_1_verileri = train[train["Öbek İsmi"] == "obek_1"]
obek_1_verileri
obek_1_verileri["Cinsiyet"].value_counts()
# Out:
# Cinsiyet
# Kadın    366
# Erkek    326
# Name: count, dtype: int64

# %%
obek_1_verileri["Yaş Grubu"].value_counts()
obek_1_verileri.corr()*100
obek_1_verileri["Yıllık Ortalama Gelir"].mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 obek_1_verileri["Yaş Grubu"].value_counts()
# ----> 2 obek_1_verileri.corr()*100
#       3 obek_1_verileri["Yıllık Ortalama Gelir"].mean()
#
# File c:\Users\seyfullahkorkmaz\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\seyfullahkorkmaz\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# ...

# %%
obek_3_verileri["Medeni Durum"].value_counts()
# Out:
# Evli     562
# Bekar    133
# Name: Medeni Durum, dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5460 entries, 0 to 5459
# Data columns (total 14 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   index                                       5460 non-null   int64
#  1   Cinsiyet                                    5460 non-null   object
#  2   Yaş Grubu                                   5460 non-null   object
#  3   Medeni Durum                                5460 non-null   object
#  4   Eğitim Düzeyi                               5460 non-null   object
#  5   İstihdam Durumu                             5460 non-null   object
#  6   Yıllık Ortalama Gelir                       5460 non-null   float64
#  7   Yaşadığı Şehir                              5460 non-null   object
#  8   En Çok İlgilendiği Ürün Grubu               5460 non-null   object
#  9   Yıllık Ortalama Satın Alım Miktarı          5460 non-null   float64
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2340 entries, 0 to 2339
# Data columns (total 13 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   index                                       2340 non-null   int64
#  1   Cinsiyet                                    2340 non-null   object
#  2   Yaş Grubu                                   2340 non-null   object
#  3   Medeni Durum                                2340 non-null   object
#  4   Eğitim Düzeyi                               2340 non-null   object
#  5   İstihdam Durumu                             2340 non-null   object
#  6   Yıllık Ortalama Gelir                       2340 non-null   float64
#  7   Yaşadığı Şehir                              2340 non-null   object
#  8   En Çok İlgilendiği Ürün Grubu               2340 non-null   object
#  9   Yıllık Ortalama Satın Alım Miktarı          2340 non-null   float64
# ...

# %%
train.isna().sum()
# Out:
# index                                         0
# Cinsiyet                                      0
# Yaş Grubu                                     0
# Medeni Durum                                  0
# Eğitim Düzeyi                                 0
# İstihdam Durumu                               0
# Yıllık Ortalama Gelir                         0
# Yaşadığı Şehir                                0
# En Çok İlgilendiği Ürün Grubu                 0
# Yıllık Ortalama Satın Alım Miktarı            0
# Yıllık Ortalama Sipariş Verilen Ürün Adedi    0
# Eğitime Devam Etme Durumu                     0
# Öbek İsmi                                     0
# Yıllık Ortalama Sepete Atılan Ürün Adedi      0
# dtype: int64

# %%
test.isna().sum()
# Out:
# index                                         0
# Cinsiyet                                      0
# Yaş Grubu                                     0
# Medeni Durum                                  0
# Eğitim Düzeyi                                 0
# İstihdam Durumu                               0
# Yıllık Ortalama Gelir                         0
# Yaşadığı Şehir                                0
# En Çok İlgilendiği Ürün Grubu                 0
# Yıllık Ortalama Satın Alım Miktarı            0
# Yıllık Ortalama Sipariş Verilen Ürün Adedi    0
# Eğitime Devam Etme Durumu                     0
# Yıllık Ortalama Sepete Atılan Ürün Adedi      0
# dtype: int64

# %%
train.describe()
# Out:
#              index  Yıllık Ortalama Gelir  Yıllık Ortalama Satın Alım Miktarı  \
# count  5460.000000           5.460000e+03                         5460.000000
# mean   2729.500000           3.635711e+05                        16616.612217
# std    1576.310566           2.197144e+05                        14099.171704
# min       0.000000           4.392299e+04                         2859.254000
# 25%    1364.750000           2.156934e+05                         4931.859057
# 50%    2729.500000           2.869254e+05                         8426.818967
# 75%    4094.250000           4.681882e+05                        30579.244695
# max    5459.000000           1.192437e+06                        48605.594415
#
#        Yıllık Ortalama Sipariş Verilen Ürün Adedi  \
# count                                 5460.000000
# mean                                    24.040884
# std                                     14.945655
# min                                      0.000000
# ...

# %%
train.dtypes
# Out:
# index                                           int64
# Cinsiyet                                       object
# Yaş Grubu                                      object
# Medeni Durum                                   object
# Eğitim Düzeyi                                  object
# İstihdam Durumu                                object
# Yıllık Ortalama Gelir                         float64
# Yaşadığı Şehir                                 object
# En Çok İlgilendiği Ürün Grubu                  object
# Yıllık Ortalama Satın Alım Miktarı            float64
# Yıllık Ortalama Sipariş Verilen Ürün Adedi    float64
# Eğitime Devam Etme Durumu                      object
# Öbek İsmi                                      object
# Yıllık Ortalama Sepete Atılan Ürün Adedi      float64
# dtype: object

# %%
train["Öbek İsmi"].value_counts()
# Out:
# obek_4    720
# obek_8    717
# obek_5    706
# obek_3    695
# obek_7    695
# obek_1    692
# obek_6    688
# obek_2    547
# Name: Öbek İsmi, dtype: int64

# %%
plt.figure(figsize=(7, 5))
sns.displot(train["Yıllık Ortalama Sipariş Verilen Ürün Adedi"])

# %%
train.corr()
# Out:
#                                                index  Yıllık Ortalama Gelir  \
# index                                       1.000000               0.036008
# Yıllık Ortalama Gelir                       0.036008               1.000000
# Yıllık Ortalama Satın Alım Miktarı          0.019259               0.740238
# Yıllık Ortalama Sipariş Verilen Ürün Adedi  0.012507               0.444398
# Yıllık Ortalama Sepete Atılan Ürün Adedi   -0.001693               0.145425
#
#                                             Yıllık Ortalama Satın Alım Miktarı  \
# index                                                                 0.019259
# Yıllık Ortalama Gelir                                                 0.740238
# Yıllık Ortalama Satın Alım Miktarı                                    1.000000
# Yıllık Ortalama Sipariş Verilen Ürün Adedi                            0.418499
# Yıllık Ortalama Sepete Atılan Ürün Adedi                              0.133864
#
# ...

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(obek_1_verileri.corr(), annot=True, cmap='coolwarm', center=0)
plt.title('Korelasyon Matrisi Heatmap')
plt.show()

# %%
train.shape
# Out:
# (5460, 14)

# %%
train["Yaşadığı Şehir"].value_counts()
# Out:
# Büyük Şehir        1959
# Küçük Şehir        1842
# Köy veya Kasaba    1092
# Kırsal              567
# Name: Yaşadığı Şehir, dtype: int64

# %%
train["Eğitim Düzeyi"].value_counts()
# Out:
# Lise Mezunu             1388
# Üniversite Mezunu       1257
# Yüksekokul Mezunu        588
# Yüksek Lisans Mezunu     545
# İlkokul Mezunu           417
# Ortaokul Mezunu          412
# Eğitimsiz                381
# Doktora Mezunu           263
# Doktora Ötesi            209
# Name: Eğitim Düzeyi, dtype: int64

# %%
train["Öbek İsmi"].value_counts()
# Out:
# obek_4    720
# obek_8    717
# obek_5    706
# obek_3    695
# obek_7    695
# obek_1    692
# obek_6    688
# obek_2    547
# Name: Öbek İsmi, dtype: int64

# %%
train["Medeni Durum"].value_counts()
# Out:
# Evli     2834
# Bekar    2626
# Name: Medeni Durum, dtype: int64

# %%
train["En Çok İlgilendiği Ürün Grubu"].value_counts()
# Out:
# Giyim                               1487
# Ev ve Mobilya                       1114
# Elektronik ve Teknolojik Ürünler    1029
# Spor Malzemeleri                    1001
# Kozmetik                             829
# Name: En Çok İlgilendiği Ürün Grubu, dtype: int64

# %%
train["Yaş Grubu"].value_counts()
# Out:
# 18-30    1841
# 31-40    1477
# 51-60     861
# 41-50     727
# >60       554
# Name: Yaş Grubu, dtype: int64

# %%
plt.scatter(train["Yıllık Ortalama Sepete Atılan Ürün Adedi"],
            train["Yıllık Ortalama Satın Alım Miktarı"])
plt.xlabel("Yıllık Ortalama Sepete Atılan Ürün Adedi")
plt.ylabel("Yıllık Ortalama Satın Alım Miktarı")

# %%
# Yaş grubuna
yasa_gore_ortalama = pd.DataFrame(train.groupby(["Öbek İsmi", "Medeni Durum"])[
                                  "Yıllık Ortalama Satın Alım Miktarı"].mean())
yasa_gore_ortalama

# %%
# Yıllara göre ürünlerin fiyat ortalamalarının artışını görselleştirme
sns.lineplot(data=yasa_gore_ortalama, x="Öbek İsmi",
             y="Yaş Grubu", hue="Yıllık Ortalama Satın Alım Miktarı")

# %%
sns.lineplot(data=train[['Yaş Grubu', 'Öbek İsmi',
             'Yıllık Ortalama Satın Alım Miktarı']])
